# %% [markdown]
# # 📦 Docker Image Information
# You are running this notebook inside a Docker container. To verify the image and version, run the following cell:

# %%
# !echo "🚀 Docker Image: ${DOCKER_IMAGE_NAME}:${VERSION}"

# %% [markdown]
# ✅ This helps ensure you're using the correct environment for reproducibility and collaboration.

# %% [markdown]
# # 📁 Download Template Repository
#
# To get started with standardized data science workflows, you can clone the latest version of the template repository. This repository contains ready-to-use templates for notebooks, scripts, and project organization.
#
# 🔗 **Github Repository:** [gabnasello/image-analysis-templates](https://github.com/gabnasello/image-analysis-templates)
#
# Run the following cell to download it:

# %%
# !git clone https://github.com/gabnasello/image-analysis-templates

# %% [markdown]
# > 💡 This will create a template folder in your current working directory. You can explore and adapt the templates to your project needs.
